# %% [markdown]
# Importar liberias

# %%
import pandas as pd
import numpy as np

# %%
pip install dateparser
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\YD148ZK\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import dateparser

# %% [markdown]
# abrir archivo CSV

# %%
pd.set_option('display.max_columns', None)
df_bank = pd.read_csv("../data/output/bank-additional.csv")
df_bank.head(5)
# Out:
#    Unnamed: 0   age        job  marital    education  default  housing  loan  \
# 0           0   NaN  housemaid  MARRIED     basic.4y      0.0      0.0   0.0
# 1           1  57.0   services  MARRIED  high.school      NaN      0.0   0.0
# 2           2  37.0   services  MARRIED  high.school      0.0      1.0   0.0
# 3           3  40.0     admin.  MARRIED     basic.6y      0.0      0.0   0.0
# 4           4  56.0   services  MARRIED  high.school      0.0      0.0   1.0
#
#      contact  duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0  telephone       261         1    999         0  NONEXISTENT           1.1
# 1  telephone       149         1    999         0  NONEXISTENT           1.1
# 2  telephone       226         1    999         0  NONEXISTENT           1.1
# 3  telephone       151         1    999         0  NONEXISTENT           1.1
# 4  telephone       307         1    999         0  NONEXISTENT           1.1
#
# ...

# %% [markdown]
# cambiar de "float" a "int" columnas : " age", "default", "housing", "loan".

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      43000 non-null  int64
#  1   age             37880 non-null  float64
#  2   job             42655 non-null  object
#  3   marital         42915 non-null  object
#  4   education       41193 non-null  object
#  5   default         34019 non-null  float64
#  6   housing         41974 non-null  float64
#  7   loan            41974 non-null  float64
#  8   contact         43000 non-null  object
#  9   duration        43000 non-null  int64
#  10  campaign        43000 non-null  int64
#  11  pdays           43000 non-null  int64
#  12  previous        43000 non-null  int64
#  13  poutcome        43000 non-null  object
#  14  emp.var.rate    43000 non-null  float64
#  15  cons.price.idx  42529 non-null  object
#  16  cons.conf.idx   43000 non-null  object
# ...

# %%
df_bank.isnull().sum()
# Out:
# Unnamed: 0           0
# age               5120
# job                345
# marital             85
# education         1807
# default           8981
# housing           1026
# loan              1026
# contact              0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx     471
# cons.conf.idx        0
# euribor3m         9256
# nr.employed          0
# y                    0
# date               248
# latitude             0
# longitude            0
# id_                  0
# dtype: int64

# %%
df_bank.isnull().mean()*100
# Out:
# Unnamed: 0         0.000000
# age               11.906977
# job                0.802326
# marital            0.197674
# education          4.202326
# default           20.886047
# housing            2.386047
# loan               2.386047
# contact            0.000000
# duration           0.000000
# campaign           0.000000
# pdays              0.000000
# previous           0.000000
# poutcome           0.000000
# emp.var.rate       0.000000
# cons.price.idx     1.095349
# cons.conf.idx      0.000000
# euribor3m         21.525581
# nr.employed        0.000000
# y                  0.000000
# date               0.576744
# latitude           0.000000
# longitude          0.000000
# id_                0.000000
# dtype: float64

# %%
df_bank.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_bank.describe().T
# Out:
#                 count          mean           std      min          25%  \
# Unnamed: 0    43000.0  20651.099047  11868.770913    0.000  10381.75000
# age           37880.0     39.977112     10.437957   17.000     32.00000
# default       34019.0      0.000088      0.009390    0.000      0.00000
# housing       41974.0      0.535998      0.498708    0.000      0.00000
# loan          41974.0      0.155620      0.362499    0.000      0.00000
# duration      43000.0    257.739279    258.666033    0.000    102.00000
# campaign      43000.0      2.567233      2.772294    1.000      1.00000
# pdays         43000.0    962.330953    187.260394    0.000    999.00000
# previous      43000.0      0.174023      0.497366    0.000      0.00000
# emp.var.rate  43000.0      0.077128      1.573898   -3.400     -1.80000
# latitude      43000.0     36.856697      7.225948   24.396     30.61475
# longitude     43000.0    -95.939067     16.752282 -124.997   -110.49425
#
# ...

# %%
df_bank["pdays"].unique()
# Out:
# array([999,   6,   4,   3,   5,   1,   0,  10,   7,   8,   9,  11,   2,
#         12,  13,  14,  15,  16,  21,  17,  18,  22,  25,  26,  19,  27,
#         20])

# %%
df_bank["pdays"].value_counts()
# Out:
# pdays
# 999    41412
# 3        457
# 6        428
# 4        121
# 9         67
# 7         66
# 2         63
# 12        61
# 10        55
# 5         50
# 13        38
# 11        30
# 15        26
# 1         26
# 14        22
# 8         20
# 0         15
# 16        13
# 17        10
# 18         7
# 22         4
# 19         3
# 21         2
# 25         1
# 26         1
# 27         1
# 20         1
# Name: count, dtype: int64

# %% [markdown]
# Para la gran mayoria de los clientes siendo "pdays": Número de días que han pasado desde la última vez que se contactó con el cliente durante esta campaña. Vemos que en el mayor de los casos el resultado es 999, por lo que no se ha contactado recientemente con la mayoria de los clientes.

# %%
df_bank["previous"].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
df_bank["previous"].value_counts()
# Out:
# previous
# 0    37103
# 1     4778
# 2      786
# 3      232
# 4       75
# 5       20
# 6        5
# 7        1
# Name: count, dtype: int64

# %% [markdown]
# Siendo la columna	previous: Número de veces que se ha contactado con el cliente antes de esta campaña. en la mayoria de los casos se ha contactado previamente "0" veces.

# %%
df_bank.select_dtypes(include="O").columns
# Out:
# Index(['job', 'marital', 'education', 'contact', 'poutcome', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'id_'],
#       dtype='object')

# %%
df_bank.select_dtypes(include="int").columns
# Out:
# Index(['Unnamed: 0', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
df_bank.select_dtypes(include="float").columns
# Out:
# Index(['age', 'default', 'housing', 'loan', 'emp.var.rate', 'latitude',
#        'longitude'],
#       dtype='object')

# %% [markdown]
# cambiar de "float" a "int" columnas : " age", "default", "housing", "loan". Pero hay nulos en estas columnas por lo que no se puede aun modificar ./
# y columna "date" tipo date - tambien tiene nulos - aunque lo primero que hay que hacer en esta columna será modificar los meses en español a ingles o numerico para que se pueda hacer el cambio a fecha

# %%
df_bank.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'latitude',
#        'longitude', 'id_'],
#       dtype='object')

# %%
df_bank.rename(columns={"id_": "ID"}, inplace=True)

# %%
df_bank.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'latitude',
#        'longitude', 'ID'],
#       dtype='object')

# %%
'''float_int = ['age', 'default','housing', 'loan']
for col in float_int:
    df_bank[col] = df_bank[col].apply(lambda x: int(x))'''
# Out:
# "float_int = ['age', 'default','housing', 'loan']\nfor col in float_int:\n    df_bank[col] = df_bank[col].apply(lambda x: int(x))"

# %%
for col in df_bank.select_dtypes(include="O").columns:
    df_bank[col] = df_bank[col].str.lower()

df_bank.tail(5)
# Out:
#        Unnamed: 0   age          job  marital            education  default  \
# 42995       19154   NaN       admin.  married    university.degree      0.0
# 42996       26206  34.0   technician  married  professional.course      0.0
# 42997       15046   NaN  blue-collar   single             basic.6y      0.0
# 42998       15280   NaN       admin.  married    university.degree      NaN
# 42999       27570   NaN   unemployed   single    university.degree      0.0
#
#        housing  loan   contact  duration  campaign  pdays  previous  \
# 42995      0.0   0.0  cellular       618         2    999         0
# 42996      1.0   1.0  cellular        42         7    999         0
# 42997      1.0   0.0  cellular       391         2    999         0
# 42998      0.0   0.0  cellular       674         3    999         0
# 42999      0.0   1.0  cellular       104         2    999         0
#
#           poutcome  emp.var.rate cons.price.idx cons.conf.idx euribor3m  \
# ...

# %%
for col in df_bank.select_dtypes(include="object").columns:
        print(col.upper())
        print(df_bank[col].value_counts())
# Out:
# JOB
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# MARITAL
# marital
# married     25999
# single      12105
# divorced     4811
# Name: count, dtype: int64
# EDUCATION
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# CONTACT
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# POUTCOME
# poutcome
# nonexistent    37103
# failure         4461
# success         1436
# Name: count, dtype: int64
# CONS.PRICE.IDX
# cons.price.idx
# 93,994    7938
# 93,918    6937
# 92,893    5985
# ...

# %%
df_bank.to_csv("../data/output/bank-additional_01.csv", index=False)
